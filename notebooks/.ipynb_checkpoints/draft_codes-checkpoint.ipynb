# %%
import requests
import scrapy
import time
import pandas as pd
from pprint import pprint
import re
import json

# %%
base_url = "https://staff.am"
main_url = base_url + "/en/jobs"

# %%
def get_relative_paths_from_one_page(page_response):
    
    relative_paths = page_response.css("div.web_item_card.hs_job_list_item a.load-more::attr(href)").getall()
    
    return relative_paths

# %%
def get_relative_paths_for_all_pages(first_page_response, base_url, delay=3):
    
    response = first_page_response
    relative_paths_for_all_pages = []
    
    while response.css("li.next a").get() is not None:
        
        relative_paths_for_all_pages.extend(get_relative_paths_from_one_page(response))
        rs = requests.get(base_url + response.css("li.next a::attr(href)").get())
        response = scrapy.http.HtmlResponse(url=rs.url, body=rs.text, encoding="utf-8")
        time.sleep(delay)
        
    relative_paths_for_all_pages.extend(get_relative_paths_from_one_page(response))
        
    return relative_paths_for_all_pages

# %%
def get_info_from_one_posting(absolute_path):
    
    rs = requests.get(absolute_path)
    response = scrapy.http.HtmlResponse(url=rs.url, body=rs.text, encoding="utf-8")
    
    extracted_data = {
        "Company_Title": response.css("h1.job_company_title::text").get(),
        "Total_views": response.css("div.col-lg-7.company_info_container p.company-page-views span::text").getall()[0],
        "Followers": response.css("div.col-lg-7.company_info_container p.company-page-views span::text").getall()[1],
        "Active_Jobs": response.css("p.company-active-job span::text").get(),
        "Jobs_History": response.css("p.company-job-history span::text").get(),
        "Job_Views": re.search("[0-9]+", response.css("div.statistics p::text").get()).group(),
        "Job_Title": response.css("div.col-lg-8 h2::text").get(),
        "Application_Deadline": re.search("Deadline: (.*)\s", response.css("div.col-lg-4.apply-btn-top p::text").get().replace("\n", " ")).group(1)
    }
    
    try:
        extracted_data["Industry"] = response.css("div.col-lg-7.company_info_container p.professional-skills-description span::text").getall()[-1]
    except IndexError:
        extracted_data["Industry"] = "None"

    job_info = [i.strip() for i in response.css("div.col-lg-6.job-info p::text").getall() if i != "\n"]
    
    extracted_data["Employment_term"] = job_info[0]
    extracted_data["Job_Category"] = job_info[1]
    extracted_data["Job_type"] = job_info[2]
    extracted_data["Job_Location"] = job_info[3]

    job_list = response.css("div.job-list-content-desc.hs_line_break")
    job_list_keys = [i.strip().replace(":", "").replace(" ", "_") for i in job_list.css("h3::text").getall()]

    if "Salary" not in job_list_keys:
        extracted_data["Salary"] = "None"
    elif "Required_candidate_level" not in job_list_keys:
        extracted_data["Required_candidate_level"] = "None"
    elif "Additional_information" not in job_list_keys:
        extracted_data["Additional_information"] = "None"

    for key in job_list_keys:
        if key == "Job_description":
            extracted_data[key] = job_list.css("p span::text, p::text").get()
        elif key == "Job_responsibilities":
            # ISSUE: If <ul> s for the field are more than 1 potential wrong collection of data
            try:
                extracted_data[key] = "\n".join(job_list.css("ul")[0].css("li span::text, li::text").getall())
            except IndexError:
                # ISSUE: If sibling <p> s are more than 1 not collected
                extracted_data[key] = "\n".join(job_list.css("h3:contains(responsibilities) + p + p::text").getall())
        elif key == "Required_qualifications":
            try:
                extracted_data[key] = "\n".join(job_list.css("ul")[1].css("li span::text, li::text").getall())
            except IndexError:
                # ISSUE: If sibling <p> s are more than 1 not collected
                extracted_data[key] = "\n".join(job_list.css("h3:contains(qualifications) + p + p::text").getall())
        elif key == "Required_candidate_level":
            extracted_data[key] = job_list.css("h3 span::text, h3::text").getall()[0]
        elif key == "Salary":
            extracted_data[key] = job_list.css("h3 span::text, h3::text").getall()[1]
        elif key == "Additional_information":
            add_info = 
            extracted_data[key] = "\n".join(job_list.css("div.additional-information p span::text, div.additional-information p::text").getall())
        else:
            extracted_data[key] = "New Field to be scraped"
            print("New Field to be scraped")
            
    skills_info_keys = [i.replace(" ", "_") for i in response.css("div.soft-skills-list.clearfix h3::text").getall()]
    
    if "Professional_skills" in skills_info_keys:
        ind = skills_info_keys.index("Professional_skills")
        extracted_data["Professional_skills"] = "\n".join(response.css("div.soft-skills-list.clearfix")[ind].css("p span::text, p::text").getall())
    else:
        extracted_data["Professional_skills"] = "None"
    if "Soft_skills" in skills_info_keys:
        ind = skills_info_keys.index("Soft_skills")
        extracted_data["Soft_skills"] = "\n".join(response.css("div.soft-skills-list.clearfix")[ind].css("p span::text, p::text").getall())
    else:
        extracted_data["Soft_skills"] = "None"

    return extracted_data

# %%
def crawl_all_postings(absolute_paths, delay=10):
    
    extracted_data = {}
    
    i = 1
    
    for path in absolute_paths:
        print(path)
        print(str(i) + "/" + str(len(absolute_paths)), "Est.: " + str(round((10 * (len(absolute_paths) - i))/60, 2)) + "m.")
        i += 1
        extracted_data_from_posting = get_info_from_one_posting(path)
        
        for key, value in extracted_data_from_posting.items():
            
            if key not in extracted_data.keys():
                
                extracted_data[key] = []
                
            extracted_data[key].append(extracted_data_from_posting[key])
        
        time.sleep(delay)
    
    return extracted_data

# %%
def crawl_all_companies(absolute_paths_companies):
    
    # TODO
# Out:
#   File "<ipython-input-423-195140bcbce4>", line 3
#     # TODO
#           ^
# SyntaxError: unexpected EOF while parsing

# %%
def main():
    
    rs = requests.get(main_url)
    response = scrapy.http.HtmlResponse(url=rs.url, body=rs.text, encoding="utf-8")

    relative_paths_for_all_pages = get_relative_paths_for_all_pages(response, base_url, delay=5)
    absolute_paths = [base_url + path for path in relative_paths_for_all_pages]
    
    extracted_data = crawl_all_postings(absolute_paths)
    
    return extracted_data

# %%
print(time.ctime())
extracted_data = main()
print(time.ctime())
# Out:
# Fri Jan 31 09:25:36 2020
# https://staff.am/en/web-php-developer-4
# 1/823 Est.: 137.0m.
# https://staff.am/en/marketing-specialist-193
# 2/823 Est.: 136.83m.
# https://staff.am/en/accountant-351
# 3/823 Est.: 136.67m.
# https://staff.am/en/chief-accountant-63
# 4/823 Est.: 136.5m.
# https://staff.am/en/naxagcog-cartaraget-2
# 5/823 Est.: 136.33m.
# https://staff.am/en/customer-service-specialist-59
# 6/823 Est.: 136.17m.
# https://staff.am/en/traffic-controller-2
# 7/823 Est.: 136.0m.
# https://staff.am/en/service-manager-5
# 8/823 Est.: 135.83m.
# https://staff.am/en/1c-system-developer-1
# 9/823 Est.: 135.67m.
# https://staff.am/en/specialist-in-lift-installation-1
# 10/823 Est.: 135.5m.
# https://staff.am/en/digital-marketing-specialist-164
# 11/823 Est.: 135.33m.
# https://staff.am/en/java-developer-intern-1
# 12/823 Est.: 135.17m.
# https://staff.am/en/java-team-lead-7
# 13/823 Est.: 135.0m.
# https://staff.am/en/hr-specialist-94
# 14/823 Est.: 134.83m.
# https://staff.am/en/senior-software-engineer-52
# 15/823 Est.: 134.67m.
# https://staff.am/en/expert-on-gender-equality-women-in-politics-project-4
# 16/823 Est.: 134.5m.
# https://staff.am/en/spanish-speaking-communication-specialist
# 17/823 Est.: 134.33m.
# https://staff.am/en/gnumner-verahskog-anvtangutyan-asxatakic
# 18/823 Est.: 134.17m.
# https://staff.am/en/active-sales-manager-10
# 19/823 Est.: 134.0m.
# https://staff.am/en/hr-managerrecruiter
# 20/823 Est.: 133.83m.
# https://staff.am/en/pahestum-banvor-sezonayin-1
# 21/823 Est.: 133.67m.
# https://staff.am/en/artadrutyan-operator-1
# 22/823 Est.: 133.5m.
# https://staff.am/en/leading-client-manager
# 23/823 Est.: 133.33m.
# https://staff.am/en/customer-service-specialist-58
# 24/823 Est.: 133.17m.
# https://staff.am/en/zbosasrjutyan-bazni-gekavar
# 25/823 Est.: 133.0m.
# https://staff.am/en/avag-varkayin-masnaget
# 26/823 Est.: 132.83m.
# https://staff.am/en/manager-35
# 27/823 Est.: 132.67m.
# https://staff.am/en/seniormid-ios-developer-9
# 28/823 Est.: 132.5m.
# https://staff.am/en/anjnakan-hayteri-kargavorman-bazni-masnaget
# 29/823 Est.: 132.33m.
# https://staff.am/en/database-developer-37
# 30/823 Est.: 132.17m.
# https://staff.am/en/mid-android-developer-9
# 31/823 Est.: 132.0m.
# https://staff.am/en/accountant-350
# 32/823 Est.: 131.83m.
# https://staff.am/en/gnumneri-masnaget-21
# 33/823 Est.: 131.67m.
# https://staff.am/en/accountant-349
# 34/823 Est.: 131.5m.
# https://staff.am/en/mediaplaner-2
# 35/823 Est.: 131.33m.
# https://staff.am/en/manual-qa-engineer-78
# 36/823 Est.: 131.17m.
# https://staff.am/en/wordpress-developer-68
# 37/823 Est.: 131.0m.
# https://staff.am/en/hr-specialist-91
# 38/823 Est.: 130.83m.
# https://staff.am/en/hasvetar-operator-22
# 39/823 Est.: 130.67m.
# https://staff.am/en/sr-software-engineer-front-end-21
# 40/823 Est.: 130.5m.
# https://staff.am/en/javascript-developer-vuejs
# 41/823 Est.: 130.33m.
# https://staff.am/en/inspektor-po-personalu-kontrol-kacestva
# 42/823 Est.: 130.17m.
# https://staff.am/en/pomosnik-v-tehniceskij-otdel-specialist-po-rng
# 43/823 Est.: 130.0m.
# https://staff.am/en/senior-golang-developer-4
# 44/823 Est.: 129.83m.
# https://staff.am/en/ip-and-transportation-networks-exploitation-senior-engineer-1
# 45/823 Est.: 129.67m.
# https://staff.am/en/junior-computer-vision-engineer
# 46/823 Est.: 129.5m.
# https://staff.am/en/leasing-leading-specialist-1
# 47/823 Est.: 129.33m.
# https://staff.am/en/transport-network-exploitation-engineer-yerevan-1
# 48/823 Est.: 129.17m.
# https://staff.am/en/tnoreni-ognakan-26
# 49/823 Est.: 129.0m.
# https://staff.am/en/recruitment-specialist-14
# 50/823 Est.: 128.83m.
# https://staff.am/en/replacing-lo-of-ra-martuni-branch-2
# 51/823 Est.: 128.67m.
# https://staff.am/en/hasvetar-37
# 52/823 Est.: 128.5m.
# https://staff.am/en/erevani-tiv-180-himnakan-dproc-poak-i-tnoreni-paston-zbagecnelu-hamar
# 53/823 Est.: 128.33m.
# https://staff.am/en/wordpress-developer-65
# 54/823 Est.: 128.17m.
# https://staff.am/en/mid-and-senior-java-engineers
# 55/823 Est.: 128.0m.
# https://staff.am/en/qa-automation-engineer-73
# 56/823 Est.: 127.83m.
# https://staff.am/en/manager-of-fb-department-1
# 57/823 Est.: 127.67m.
# https://staff.am/en/graphic-designer-306
# 58/823 Est.: 127.5m.
# https://staff.am/en/pvk-profilneri-ekstruziayi-artadramasi-patasxanatu-1
# 59/823 Est.: 127.33m.
# https://staff.am/en/tour-guide-5
# 60/823 Est.: 127.17m.
# https://staff.am/en/branch-manager-12
# 61/823 Est.: 127.0m.
# https://staff.am/en/junior-full-stack-developer-5
# 62/823 Est.: 126.83m.
# https://staff.am/en/power-systems-exploitation-engineer-2
# 63/823 Est.: 126.67m.
# https://staff.am/en/logistics-manager-29
# 64/823 Est.: 126.5m.
# https://staff.am/en/consultant-8
# 65/823 Est.: 126.33m.
# https://staff.am/en/incoming-tour-manager-26
# 66/823 Est.: 126.17m.
# https://staff.am/en/import-specialist-21
# 67/823 Est.: 126.0m.
# https://staff.am/en/oraki-verahskman-masnaget-5
# 68/823 Est.: 125.83m.
# https://staff.am/en/engineering-instructor-2
# 69/823 Est.: 125.67m.
# https://staff.am/en/collector-of-artik-branch-and-maralik-representation
# 70/823 Est.: 125.5m.
# https://staff.am/en/receptionist-163
# 71/823 Est.: 125.33m.
# https://staff.am/en/hh-siraki-marzi-gyumru-tiv-6-himnakan-dproc-poak-i-tnoreni-paston-zbagecnelu-hamar-4
# 72/823 Est.: 125.17m.
# https://staff.am/en/mardkayin-resursneri-karavaric-6
# 73/823 Est.: 125.0m.
# https://staff.am/en/senior-net-developer-110
# 74/823 Est.: 124.83m.
# https://staff.am/en/turkish-speaking-customer-support-specialist-10
# 75/823 Est.: 124.67m.
# https://staff.am/en/specialist-call-centra-40
# 76/823 Est.: 124.5m.
# https://staff.am/en/sukayi-zargacman-patasxanatu-18
# 77/823 Est.: 124.33m.
# https://staff.am/en/marketing-manager-105
# 78/823 Est.: 124.17m.
# https://staff.am/en/senior-and-middle-angular-developers-2
# 79/823 Est.: 124.0m.
# https://staff.am/en/head-of-product-development-department
# 80/823 Est.: 123.83m.
# https://staff.am/en/celtatefltesol-english-tutors-2
# 81/823 Est.: 123.67m.
# https://staff.am/en/pr-and-advertising-manager
# 82/823 Est.: 123.5m.
# https://staff.am/en/project-manager-184
# 83/823 Est.: 123.33m.
# https://staff.am/en/hh-kotayki-marzi-karenisi-mijnakarg-dproc-poak-i-gorcadir-marmni-tnoreni-paston-zbagecnelu-hamar
# 84/823 Est.: 123.17m.
# https://staff.am/en/hh-siraki-marzi-gyumru-tiv-9-himnakan-dproc-poak-i-tnoreni-paston-zbagecnelu-hamar
# 85/823 Est.: 123.0m.
# https://staff.am/en/coordinator-of-rates-2
# 86/823 Est.: 122.83m.
# https://staff.am/en/sales-specialist-54
# 87/823 Est.: 122.67m.
# https://staff.am/en/nergna-tur-menejer-7
# 88/823 Est.: 122.5m.
# https://staff.am/en/lo-of-vedi-representation
# 89/823 Est.: 122.33m.
# https://staff.am/en/lo-of-spitak-representation
# 90/823 Est.: 122.17m.
# https://staff.am/en/python-developer-83
# 91/823 Est.: 122.0m.
# https://staff.am/en/web-designer-47
# 92/823 Est.: 121.83m.
# https://staff.am/en/sales-manager-part-time-1
# 93/823 Est.: 121.67m.
# https://staff.am/en/accountant-348
# 94/823 Est.: 121.5m.
# https://staff.am/en/officer-of-dilijan-representation
# 95/823 Est.: 121.33m.
# https://staff.am/en/elektronayin-inzener
# 96/823 Est.: 121.17m.
# New Field to be scraped
# https://staff.am/en/digital-marketing-specialist-161
# 97/823 Est.: 121.0m.
# https://staff.am/en/vacarki-menejer-82
# 98/823 Est.: 120.83m.
# https://staff.am/en/monitoring-and-evaluation-me-consultant
# 99/823 Est.: 120.67m.
# https://staff.am/en/it-project-manager-systems-analyst-10
# 100/823 Est.: 120.5m.
# New Field to be scraped
# https://staff.am/en/graphic-designer-304
# 101/823 Est.: 120.33m.
# https://staff.am/en/cucasrahi-menejer
# 102/823 Est.: 120.17m.
# https://staff.am/en/php-or-js-trainer-1
# 103/823 Est.: 120.0m.
# https://staff.am/en/back-end-developer-38
# 104/823 Est.: 119.83m.
# https://staff.am/en/hrhuman-resourcessales
# 105/823 Est.: 119.67m.
# https://staff.am/en/nodejs-developer---backend
# 106/823 Est.: 119.5m.
# https://staff.am/en/merchandiser-23
# 107/823 Est.: 119.33m.
# https://staff.am/en/teller-15
# 108/823 Est.: 119.17m.
# https://staff.am/en/sales-consultant-250
# 109/823 Est.: 119.0m.
# https://staff.am/en/general-english-instructor-extension-program-1
# 110/823 Est.: 118.83m.
# https://staff.am/en/eastern-armenian-instructor
# 111/823 Est.: 118.67m.
# https://staff.am/en/mid-level-c-developer-1
# 112/823 Est.: 118.5m.
# https://staff.am/en/personal-banker-11
# 113/823 Est.: 118.33m.
# https://staff.am/en/product-owner-92
# 114/823 Est.: 118.17m.
# https://staff.am/en/meeter-greeter
# 115/823 Est.: 118.0m.
# https://staff.am/en/middlesenior-javascript-developer-1
# 116/823 Est.: 117.83m.
# https://staff.am/en/loan-and-deposit-operational-officer
# 117/823 Est.: 117.67m.
# https://staff.am/en/wordpress-guru-1
# 118/823 Est.: 117.5m.
# https://staff.am/en/sef-xoharar
# 119/823 Est.: 117.33m.
# https://staff.am/en/python-developer-80
# 120/823 Est.: 117.17m.
# https://staff.am/en/senior-ios-engineer-for-open-source-project
# 121/823 Est.: 117.0m.
# https://staff.am/en/mid-level-full-stack-developer-9
# 122/823 Est.: 116.83m.
# https://staff.am/en/mid-level-react-native-developer
# 123/823 Est.: 116.67m.
# https://staff.am/en/sr-full-stack-developer
# 124/823 Est.: 116.5m.
# https://staff.am/en/sr-react-native-developer
# 125/823 Est.: 116.33m.
# https://staff.am/en/android-developer-150
# 126/823 Est.: 116.17m.
# https://staff.am/en/team-lead-senior-php-developer-9
# 127/823 Est.: 116.0m.
# https://staff.am/en/1c-implementation-and-service-specialist-1
# 128/823 Est.: 115.83m.
# https://staff.am/en/researcherassistant
# 129/823 Est.: 115.67m.
# https://staff.am/en/full-stack-web-developer-71
# 130/823 Est.: 115.5m.
# https://staff.am/en/employer-branding-communications-specialist
# 131/823 Est.: 115.33m.
# https://staff.am/en/graphic-designer-303
# 132/823 Est.: 115.17m.
# New Field to be scraped
# https://staff.am/en/texnikakan-ajakcutyan-masnaget-13
# 133/823 Est.: 115.0m.
# https://staff.am/en/call-center-operator-57
# 134/823 Est.: 114.83m.
# https://staff.am/en/internship-opportunity-in-promotion-and-protection-of-human-rights-in-armenia-project
# 135/823 Est.: 114.67m.
# https://staff.am/en/business-development-executive-7
# 136/823 Est.: 114.5m.
# https://staff.am/en/logistics-manager-27
# 137/823 Est.: 114.33m.
# https://staff.am/en/treasury-department-specialist-dealer-3
# 138/823 Est.: 114.17m.
# https://staff.am/en/sparogakan-varkavorman-masnaget-noyemberyan-masnacyugum
# 139/823 Est.: 114.0m.
# https://staff.am/en/loan-officer-in-tashir-branch
# 140/823 Est.: 113.83m.
# https://staff.am/en/full-stack-net-developer-14
# 141/823 Est.: 113.67m.
# https://staff.am/en/teller-in-vardenis-branch
# 142/823 Est.: 113.5m.
# https://staff.am/en/senior-backendfullstack-developer
# 143/823 Est.: 113.33m.
# https://staff.am/en/frontendfullstack-developer-mid
# 144/823 Est.: 113.17m.
# https://staff.am/en/executive-assistanttranslator-3
# 145/823 Est.: 113.0m.
# https://staff.am/en/vacarki-menejer-79
# 146/823 Est.: 112.83m.
# https://staff.am/en/office-activity-coordinator
# 147/823 Est.: 112.67m.
# https://staff.am/en/chief-accountant-62
# 148/823 Est.: 112.5m.
# https://staff.am/en/web-engineer-3
# 149/823 Est.: 112.33m.
# https://staff.am/en/vacarki-timi-gekavar-2
# 150/823 Est.: 112.17m.
# https://staff.am/en/accountant-347
# 151/823 Est.: 112.0m.
# https://staff.am/en/hh-armaviri-marzi-vagarsapati-m-gorku-anvan-tiv-5-avag-dproc-poak-i-tnoreni-paston-zbagecnelu-hamar-4
# 152/823 Est.: 111.83m.
# https://staff.am/en/contract-management-senior-lawyer-5
# 153/823 Est.: 111.67m.
# https://staff.am/en/marketing-communications-and-events-manager-2
# 154/823 Est.: 111.5m.
# https://staff.am/en/technical-support-specialist---night-shift-7
# 155/823 Est.: 111.33m.
# https://staff.am/en/product-owner-89
# 156/823 Est.: 111.17m.
# https://staff.am/en/midsenior-nodejs-developer
# 157/823 Est.: 111.0m.
# https://staff.am/en/ios-developer-161
# 158/823 Est.: 110.83m.
# https://staff.am/en/manager-34
# 159/823 Est.: 110.67m.
# https://staff.am/en/artadrutyan-hasvetar-2
# 160/823 Est.: 110.5m.
# https://staff.am/en/gaming-operations-specialist-16
# 161/823 Est.: 110.33m.
# https://staff.am/en/finance-manager-3
# 162/823 Est.: 110.17m.
# https://staff.am/en/microbiologist-5
# 163/823 Est.: 110.0m.
# New Field to be scraped
# https://staff.am/en/react-developer-19
# 164/823 Est.: 109.83m.
# https://staff.am/en/junior-procurement-specialist-7
# 165/823 Est.: 109.67m.
# https://staff.am/en/avag-ganjapah
# 166/823 Est.: 109.5m.
# https://staff.am/en/ndhanur-gorcerov-iravakan-spasarkman-bazni-glxavor-masnaget
# 167/823 Est.: 109.33m.
# https://staff.am/en/hostess-11
# 168/823 Est.: 109.17m.
# https://staff.am/en/manual-qa-tester-21
# 169/823 Est.: 109.0m.
# https://staff.am/en/manual-qa-tester-18
# 170/823 Est.: 108.83m.
# https://staff.am/en/hh-siraki-marzi-sagiki-himnakan-dproc-poak-i-tnoreni-paston-zbagecnelu-hamar
# 171/823 Est.: 108.67m.
# https://staff.am/en/translator-serbian-swedish-malay
# 172/823 Est.: 108.5m.
# https://staff.am/en/translator-danish-romanian
# 173/823 Est.: 108.33m.
# https://staff.am/en/social-media-marketing-specialist-20
# 174/823 Est.: 108.17m.
# https://staff.am/en/it-business-analyst-30
# 175/823 Est.: 108.0m.
# https://staff.am/en/artasat-kagakum-tarecneri-tnayin-xnamk-ev-pokrik-isxan-erexaneri-cerekayin-kentron-cragreri-gekavar
# 176/823 Est.: 107.83m.
# https://staff.am/en/senior-sql-db-administrator-with-development-skills
# 177/823 Est.: 107.67m.
# https://staff.am/en/ia-gcov-datakan-brnaganjman-bazni-masnaget
# 178/823 Est.: 107.5m.
# https://staff.am/en/senior-software-engineer-nodejs-oriented-7
# 179/823 Est.: 107.33m.
# https://staff.am/en/sales-manager-280
# 180/823 Est.: 107.17m.
# https://staff.am/en/international-shipping-coordinator-1
# 181/823 Est.: 107.0m.
# https://staff.am/en/uiux-designer-255
# 182/823 Est.: 106.83m.
# https://staff.am/en/hasvarog-artadramasum-1
# 183/823 Est.: 106.67m.
# New Field to be scraped
# New Field to be scraped
# https://staff.am/en/pr-and-communications-specialist-1
# 184/823 Est.: 106.5m.
# https://staff.am/en/office-manager-127
# 185/823 Est.: 106.33m.
# New Field to be scraped
# New Field to be scraped
# https://staff.am/en/hasvapah-118
# 186/823 Est.: 106.17m.
# https://staff.am/en/hasvetar-34
# 187/823 Est.: 106.0m.
# https://staff.am/en/operator-53
# 188/823 Est.: 105.83m.
# https://staff.am/en/customer-service-representative---phone-email-and-chat-1
# 189/823 Est.: 105.67m.
# https://staff.am/en/hr-specialist-90
# 190/823 Est.: 105.5m.
# https://staff.am/en/legal-advisor-consultant
# 191/823 Est.: 105.33m.
# https://staff.am/en/business-development-manager-38
# 192/823 Est.: 105.17m.
# https://staff.am/en/cashier-37
# 193/823 Est.: 105.0m.
# https://staff.am/en/accountant-346
# 194/823 Est.: 104.83m.
# https://staff.am/en/nacalnik-otdela-magazina-sportmaster
# 195/823 Est.: 104.67m.
# https://staff.am/en/full-stack-developer-81
# 196/823 Est.: 104.5m.
# https://staff.am/en/computer-vision-engineer-46
# 197/823 Est.: 104.33m.
# https://staff.am/en/horeka-menejer-arakic
# 198/823 Est.: 104.17m.
# https://staff.am/en/arakic-36
# 199/823 Est.: 104.0m.
# https://staff.am/en/fixed-services-and-mbb-product-owner
# 200/823 Est.: 103.83m.
# https://staff.am/en/call-center-specialist-63
# 201/823 Est.: 103.67m.
# https://staff.am/en/scholar-in-residence
# 202/823 Est.: 103.5m.
# https://staff.am/en/mice-coordinator
# 203/823 Est.: 103.33m.
# https://staff.am/en/senior-qa-engineer
# 204/823 Est.: 103.17m.
# https://staff.am/en/buzatexnikakan-hanjnazogovi-andam-1
# 205/823 Est.: 103.0m.
# https://staff.am/en/call-centre-agent-7
# 206/823 Est.: 102.83m.
# https://staff.am/en/php-developer-177
# 207/823 Est.: 102.67m.
# https://staff.am/en/project-manager-181
# 208/823 Est.: 102.5m.
# https://staff.am/en/it-support-engineer
# 209/823 Est.: 102.33m.
# https://staff.am/en/vacarog-xorhrdatu-54
# 210/823 Est.: 102.17m.
# New Field to be scraped
# New Field to be scraped
# https://staff.am/en/react-js-developer-31
# 211/823 Est.: 102.0m.
# https://staff.am/en/net-developer-130
# 212/823 Est.: 101.83m.
# https://staff.am/en/reporting-analyst-15
# 213/823 Est.: 101.67m.
# https://staff.am/en/android-developer-141
# 214/823 Est.: 101.5m.
# https://staff.am/en/oraki-karavarman-ev-gorcnkerneri-ajakcutyan-menejer-11
# 215/823 Est.: 101.33m.
# https://staff.am/en/cfo
# 216/823 Est.: 101.17m.
# https://staff.am/en/relationship-manager
# 217/823 Est.: 101.0m.
# https://staff.am/en/hh-aragacotni-marzi-hakoyi-himnakan-dproc-poak-i-tnoreni-paston-zbagecnelu-hamar-4
# 218/823 Est.: 100.83m.
# https://staff.am/en/salesforce-developer
# 219/823 Est.: 100.67m.
# https://staff.am/en/hh-vayoc-jori-marzi-getapi-mijnakarg-dproc-poak-i-tnoreni-paston-zbagecnelu-hamar
# 220/823 Est.: 100.5m.
# https://staff.am/en/smm-specialist-201
# 221/823 Est.: 100.33m.
# https://staff.am/en/sales-and-customer-service-center-specialist-c-yerevan-1
# 222/823 Est.: 100.17m.
# https://staff.am/en/nermucumneri-gcov-masnaget-7
# 223/823 Est.: 100.0m.
# https://staff.am/en/hasvapah-111
# 224/823 Est.: 99.83m.
# https://staff.am/en/sarkavorumneri-portfeli-masnaget
# 225/823 Est.: 99.67m.
# https://staff.am/en/react-native-mobile-developer
# 226/823 Est.: 99.5m.
# https://staff.am/en/geschaftsfuhrer-dwv-armenien
# 227/823 Est.: 99.33m.
# https://staff.am/en/hr-specialist-88
# 228/823 Est.: 99.17m.
# https://staff.am/en/java-developer-72
# 229/823 Est.: 99.0m.
# https://staff.am/en/administrative-assistant-125
# 230/823 Est.: 98.83m.
# https://staff.am/en/qa-engineer-352
# 231/823 Est.: 98.67m.
# https://staff.am/en/hh-aragacotni-marzi-ohanavani-s-avetisyani-anvan-mijnakarg-dproc-poak-i-gorcadir-marmni-tnoreni-pastonn-zbagecnelu-hamar
# 232/823 Est.: 98.5m.
# https://staff.am/en/store-supervisor
# 233/823 Est.: 98.33m.
# https://staff.am/en/sales-consultant-249
# 234/823 Est.: 98.17m.
# https://staff.am/en/marketing-and-sales-development-specialist
# 235/823 Est.: 98.0m.
# https://staff.am/en/data-scientist-51
# 236/823 Est.: 97.83m.
# https://staff.am/en/senior-back-end-developer-16
# 237/823 Est.: 97.67m.
# https://staff.am/en/middle-front-end-developer-10
# 238/823 Est.: 97.5m.
# https://staff.am/en/digital-marketing-expert-15
# 239/823 Est.: 97.33m.
# https://staff.am/en/mid-level-back-endwordpress-developer-1
# 240/823 Est.: 97.17m.
# https://staff.am/en/store-director
# 241/823 Est.: 97.0m.
# https://staff.am/en/hacaxordneri-ajakcman-masnaget-gyumrium
# 242/823 Est.: 96.83m.
# https://staff.am/en/accountant-343
# 243/823 Est.: 96.67m.
# https://staff.am/en/reconciliation-specialist-8
# 244/823 Est.: 96.5m.
# https://staff.am/en/farsi-speaking-customer-support-representative-7
# 245/823 Est.: 96.33m.
# https://staff.am/en/monitoring-representative-1
# 246/823 Est.: 96.17m.
# https://staff.am/en/senior-uiux-designer-21
# 247/823 Est.: 96.0m.
# New Field to be scraped
# https://staff.am/en/copywriter-46
# 248/823 Est.: 95.83m.
# https://staff.am/en/nergna-turizmi-ev-tomseri-vacarki-gorcakalner
# 249/823 Est.: 95.67m.
# https://staff.am/en/call-center-agent-at-your-service-agent-5
# 250/823 Est.: 95.5m.
# https://staff.am/en/billing-systems-support-leading-specialist
# 251/823 Est.: 95.33m.
# https://staff.am/en/front-desk-clerk-10
# 252/823 Est.: 95.17m.
# https://staff.am/en/graphic-designer-298
# 253/823 Est.: 95.0m.
# https://staff.am/en/hh-tavusi-marzi-ijevani-tiv-1-himnakan-dproc-poak-i-tnoreni-paston-zbagecnelu-hamar
# 254/823 Est.: 94.83m.
# https://staff.am/en/hh-aragacotni-marzi-verin-sasnaseni-martun-manukyani-anvan-himnakan-dproc-poak-i-tnoreni-paston-zbagecnelu-hamar
# 255/823 Est.: 94.67m.
# https://staff.am/en/digital-product-owner-4
# 256/823 Est.: 94.5m.
# https://staff.am/en/hh-siraki-marzi-gusanagyugi-mijnakarg-dproc-poak-i-gorcadir-marmni-tnoreni-paston-zbagecnelu-hamar
# 257/823 Est.: 94.33m.
# https://staff.am/en/junior-customer-success-manager-6
# 258/823 Est.: 94.17m.
# https://staff.am/en/senior-accountant-47
# 259/823 Est.: 94.0m.
# https://staff.am/en/javadata-engineer
# 260/823 Est.: 93.83m.
# https://staff.am/en/copywriter-43
# 261/823 Est.: 93.67m.
# https://staff.am/en/data-scientist-48
# 262/823 Est.: 93.5m.
# https://staff.am/en/google-adwords-facebook-ads-expert
# 263/823 Est.: 93.33m.
# https://staff.am/en/sales-consultant-248
# 264/823 Est.: 93.17m.
# https://staff.am/en/specialist-po-zakupkam-19
# 265/823 Est.: 93.0m.
# https://staff.am/en/service-specialist-burberry-armani-ermenegildo-zegna
# 266/823 Est.: 92.83m.
# https://staff.am/en/incoming-tour-manager-22
# 267/823 Est.: 92.67m.
# https://staff.am/en/react-native-developer-55
# 268/823 Est.: 92.5m.
# https://staff.am/en/hardware-services-project-manager
# 269/823 Est.: 92.33m.
# https://staff.am/en/senior-qa-engineer-mfd-1
# 270/823 Est.: 92.17m.
# https://staff.am/en/master-data-specialist-12
# 271/823 Est.: 92.0m.
# https://staff.am/en/brand-manager-59
# 272/823 Est.: 91.83m.
# https://staff.am/en/corporate-trainer-12
# 273/823 Est.: 91.67m.
# https://staff.am/en/hh-loru-marzi-sarcapeti-mijnakarg-dproc-poak-i-tnoreni-paston-zbagecnelu-hamar
# 274/823 Est.: 91.5m.
# https://staff.am/en/ganjapah-33
# 275/823 Est.: 91.33m.
# https://staff.am/en/iravabanakan-bazni-gekavar
# 276/823 Est.: 91.17m.
# https://staff.am/en/tumo-dilijan-info-desk-and-registration-coordinator-4
# 277/823 Est.: 91.0m.
# https://staff.am/en/java-engineer-30
# 278/823 Est.: 90.83m.
# https://staff.am/en/mid-level-php-developer-21
# 279/823 Est.: 90.67m.
# https://staff.am/en/graphic-design-workshop-leader-content-developer-9
# 280/823 Est.: 90.5m.
# https://staff.am/en/motion-graphics-workshop-leadercontent-developer-6
# 281/823 Est.: 90.33m.
# https://staff.am/en/software-development-manager-4
# 282/823 Est.: 90.17m.
# https://staff.am/en/artadrakan-tegamasi-patasxanatu-1
# 283/823 Est.: 90.0m.
# https://staff.am/en/react-native-developer-52
# 284/823 Est.: 89.83m.
# https://staff.am/en/digitain-food-court-digibar-and-event-manager
# 285/823 Est.: 89.67m.
# https://staff.am/en/executive-chef-3
# 286/823 Est.: 89.5m.
# https://staff.am/en/hasvapah-hasvetar-4
# 287/823 Est.: 89.33m.
# https://staff.am/en/branch-manager-9
# 288/823 Est.: 89.17m.
# https://staff.am/en/video-timi-koordinator-erekoyan-hertapox-1
# 289/823 Est.: 89.0m.
# https://staff.am/en/project-manager-180
# 290/823 Est.: 88.83m.
# https://staff.am/en/erevani-n-agbalyani-anvan-tiv-19-himnakan-dproc-poak-i-tnoreni-paston-zbagecnelu-hamar
# 291/823 Est.: 88.67m.
# https://staff.am/en/hh-kotayki-marzi-hrazdani-tiv-2-himnakan-dproc-poak-i-gorcadir-marmni-tnoreni-paston-zbagecnelu-hamar
# 292/823 Est.: 88.5m.
# https://staff.am/en/associate-project-manager-10
# 293/823 Est.: 88.33m.
# https://staff.am/en/engineering-manager-java-microservices-data-1
# 294/823 Est.: 88.17m.
# https://staff.am/en/engineering-manager-mobile-androidios-1
# 295/823 Est.: 88.0m.
# https://staff.am/en/lead-senior-it-engineer-1
# 296/823 Est.: 87.83m.
# https://staff.am/en/senior-c-engineer-9
# 297/823 Est.: 87.67m.
# https://staff.am/en/seniorlead-technical-product-manager---data-insights-1
# 298/823 Est.: 87.5m.
# https://staff.am/en/anvtangutyan-asxatakic-20
# 299/823 Est.: 87.33m.
# https://staff.am/en/senior-c-engineer-mfd-hayq-4
# 300/823 Est.: 87.17m.
# https://staff.am/en/data-engineer-30
# 301/823 Est.: 87.0m.
# https://staff.am/en/senior-database-developer
# 302/823 Est.: 86.83m.
# https://staff.am/en/material-science-engineer-7
# 303/823 Est.: 86.67m.
# https://staff.am/en/mid-android-developer-6
# 304/823 Est.: 86.5m.
# https://staff.am/en/graphic-designer-at-mccann-yerevan-1
# 305/823 Est.: 86.33m.
# https://staff.am/en/marketing-specialist-190
# 306/823 Est.: 86.17m.
# https://staff.am/en/hr-assistant-29
# 307/823 Est.: 86.0m.
# https://staff.am/en/spasarkman-kentronneri-tnoren
# 308/823 Est.: 85.83m.
# https://staff.am/en/brewery-general-manager-1
# 309/823 Est.: 85.67m.
# https://staff.am/en/business-analyst-55
# 310/823 Est.: 85.5m.
# https://staff.am/en/legal-adviser-18
# 311/823 Est.: 85.33m.
# https://staff.am/en/qa-automation-engineer-67
# 312/823 Est.: 85.17m.
# https://staff.am/en/sales-manager-277
# 313/823 Est.: 85.0m.
# https://staff.am/en/back-end-developer-34
# 314/823 Est.: 84.83m.
# https://staff.am/en/c-engineer-mfd-remote-management-1
# 315/823 Est.: 84.67m.
# https://staff.am/en/ux-designer-mfd-remote-management-1
# 316/823 Est.: 84.5m.
# https://staff.am/en/sales-specialist-51
# 317/823 Est.: 84.33m.
# https://staff.am/en/user-success-support-specialist-1
# 318/823 Est.: 84.17m.
# https://staff.am/en/sports-trader-1
# 319/823 Est.: 84.0m.
# https://staff.am/en/banking-operations-intern
# 320/823 Est.: 83.83m.
# https://staff.am/en/product-manager-machine-learning-and-artificial-intelligence-1
# 321/823 Est.: 83.67m.
# https://staff.am/en/marketing-project-manager-9
# 322/823 Est.: 83.5m.
# https://staff.am/en/senior-c-developer-mfd-pilot-1
# 323/823 Est.: 83.33m.
# https://staff.am/en/data-annotation-specialist
# 324/823 Est.: 83.17m.
# https://staff.am/en/web-developer-86
# 325/823 Est.: 83.0m.
# https://staff.am/en/senior-c-engineer-mfd-tensor
# 326/823 Est.: 82.83m.
# https://staff.am/en/senior-full-stack-engineer-mfd-tensor
# 327/823 Est.: 82.67m.
# https://staff.am/en/product-manager-108
# 328/823 Est.: 82.5m.
# https://staff.am/en/customer-service-specialist-55
# 329/823 Est.: 82.33m.
# https://staff.am/en/javascript-developer-65
# 330/823 Est.: 82.17m.
# https://staff.am/en/ui-developer-30
# 331/823 Est.: 82.0m.
# https://staff.am/en/junior-digital-marketing-specialist
# 332/823 Est.: 81.83m.
# https://staff.am/en/corporate-customers-call-center-specialist-1
# 333/823 Est.: 81.67m.
# https://staff.am/en/executive-assistant-61
# 334/823 Est.: 81.5m.
# https://staff.am/en/mechanic-19
# 335/823 Est.: 81.33m.
# https://staff.am/en/product-owner-mfd-iot-1
# 336/823 Est.: 81.17m.
# https://staff.am/en/digital-marketing-specialist-157
# 337/823 Est.: 81.0m.
# https://staff.am/en/data-associate-2
# 338/823 Est.: 80.83m.
# https://staff.am/en/seo-specialist-55
# 339/823 Est.: 80.67m.
# https://staff.am/en/lawyer-67
# 340/823 Est.: 80.5m.
# https://staff.am/en/team-manager-mfd-tensor
# 341/823 Est.: 80.33m.
# https://staff.am/en/senior-ios-developer-mfd-teamviewer-tensor-1
# 342/823 Est.: 80.17m.
# https://staff.am/en/scrum-master-mfd-remote-management-1
# 343/823 Est.: 80.0m.
# https://staff.am/en/full-stack-developer-mfd-remote-management-1
# 344/823 Est.: 79.83m.
# https://staff.am/en/production-operator-9
# 345/823 Est.: 79.67m.
# https://staff.am/en/quality-control-manager-9
# 346/823 Est.: 79.5m.
# https://staff.am/en/senior-qa-engineer-123
# 347/823 Est.: 79.33m.
# https://staff.am/en/product-manager-105
# 348/823 Est.: 79.17m.
# https://staff.am/en/senior-fullstack-net-3
# 349/823 Est.: 79.0m.
# https://staff.am/en/menejer-arakic-lgh-um
# 350/823 Est.: 78.83m.
# https://staff.am/en/senior-devops-engineer-7
# 351/823 Est.: 78.67m.
# https://staff.am/en/senior-android-developer-80
# 352/823 Est.: 78.5m.
# https://staff.am/en/high-value-customer-support-specialist-1
# 353/823 Est.: 78.33m.
# https://staff.am/en/software-developer-54
# 354/823 Est.: 78.17m.
# New Field to be scraped
# https://staff.am/en/partner-support-specialist
# 355/823 Est.: 78.0m.
# https://staff.am/en/artadrakan-hoskagceri-elektrik-4
# 356/823 Est.: 77.83m.
# https://staff.am/en/vacaroguhi-xorhrdatuganjapah
# 357/823 Est.: 77.67m.
# https://staff.am/en/lawyer-66
# 358/823 Est.: 77.5m.
# https://staff.am/en/digital-marketing-specialist-156
# 359/823 Est.: 77.33m.
# https://staff.am/en/field-support-specialist-1
# 360/823 Est.: 77.17m.
# https://staff.am/en/project-manager-177
# 361/823 Est.: 77.0m.
# https://staff.am/en/front-end-developer-188
# 362/823 Est.: 76.83m.
# https://staff.am/en/net-developer-126
# 363/823 Est.: 76.67m.
# https://staff.am/en/client-adviser-in-gyumri-branch-2
# 364/823 Est.: 76.5m.
# https://staff.am/en/business-analyst-52
# 365/823 Est.: 76.33m.
# https://staff.am/en/senior-uiux-designer-18
# 366/823 Est.: 76.17m.
# https://staff.am/en/python-django-developer
# 367/823 Est.: 76.0m.
# https://staff.am/en/tax-and-accounting-specialist-tax-and-legal-department
# 368/823 Est.: 75.83m.
# https://staff.am/en/frontend-reactjs-developer
# 369/823 Est.: 75.67m.
# https://staff.am/en/senior-ios-developer-60
# 370/823 Est.: 75.5m.
# https://staff.am/en/marketing-and-smm
# 371/823 Est.: 75.33m.
# https://staff.am/en/marketing-assistant-7
# 372/823 Est.: 75.17m.
# https://staff.am/en/erevani-tiv-159-avag-dproc-poak-i-tnoreni-pastonn-zbagecnelu-hamar
# 373/823 Est.: 75.0m.
# https://staff.am/en/hh-tavusi-marzi-baganisi-mijnakarg-dproc-poak-i-tnoreni-paston-zbagecnelu-hamar
# 374/823 Est.: 74.83m.
# https://staff.am/en/inzener-18
# 375/823 Est.: 74.67m.
# https://staff.am/en/office-manager-123
# 376/823 Est.: 74.5m.
# https://staff.am/en/accountant-341
# 377/823 Est.: 74.33m.
# https://staff.am/en/finansakan-bazhni-ognakan-8
# 378/823 Est.: 74.17m.
# https://staff.am/en/database-developer-ms-sql-1
# 379/823 Est.: 74.0m.
# https://staff.am/en/incouming-tour-manager
# 380/823 Est.: 73.83m.
# https://staff.am/en/ui-coder-frontend-developer
# 381/823 Est.: 73.67m.
# https://staff.am/en/housekeeping-manager-6
# 382/823 Est.: 73.5m.
# https://staff.am/en/graphic-designer-297
# 383/823 Est.: 73.33m.
# https://staff.am/en/retail-store-representative
# 384/823 Est.: 73.17m.
# https://staff.am/en/internal-sales-representative
# 385/823 Est.: 73.0m.
# https://staff.am/en/degaget-degagorc-k-sevanum
# 386/823 Est.: 72.83m.
# https://staff.am/en/mid-net-engineer
# 387/823 Est.: 72.67m.
# https://staff.am/en/users-support-and-incidents-management-engineer-1
# 388/823 Est.: 72.5m.
# https://staff.am/en/web-designer-44
# 389/823 Est.: 72.33m.
# https://staff.am/en/project-manager-of-fixedfmc-productsservices-5
# 390/823 Est.: 72.17m.
# https://staff.am/en/learning-coach-in-gyumri-7
# 391/823 Est.: 72.0m.
# https://staff.am/en/vacarki-menejer-75
# 392/823 Est.: 71.83m.
# https://staff.am/en/graphic-designer-209
# 393/823 Est.: 71.67m.
# https://staff.am/en/python-developer-77
# 394/823 Est.: 71.5m.
# https://staff.am/en/coordinator-in-the-contests-department
# 395/823 Est.: 71.33m.
# https://staff.am/en/expert-on-marketing-analysis-2
# 396/823 Est.: 71.17m.
# https://staff.am/en/itinformation-technoloigy-supervisor
# 397/823 Est.: 71.0m.
# https://staff.am/en/nodejs-developer-54
# 398/823 Est.: 70.83m.
# https://staff.am/en/chimical-laboratorer
# 399/823 Est.: 70.67m.
# https://staff.am/en/lawyer-65
# 400/823 Est.: 70.5m.
# https://staff.am/en/corporate-sales-senior-specialist-21
# 401/823 Est.: 70.33m.
# https://staff.am/en/administrative-assistant-122
# 402/823 Est.: 70.17m.
# https://staff.am/en/sales-agent-12
# 403/823 Est.: 70.0m.
# https://staff.am/en/human-resourcessales
# 404/823 Est.: 69.83m.
# https://staff.am/en/hr-talent-acquisition-manager
# 405/823 Est.: 69.67m.
# https://staff.am/en/marketing-and-sales-manager-8
# 406/823 Est.: 69.5m.
# https://staff.am/en/it-support-specialist-39
# 407/823 Est.: 69.33m.
# https://staff.am/en/sparogakan-varkavorman-masnaget-ejmiacin-masnacyugum-1
# 408/823 Est.: 69.17m.
# https://staff.am/en/production-operator-5
# 409/823 Est.: 69.0m.
# https://staff.am/en/marketing-specialist-187
# 410/823 Est.: 68.83m.
# https://staff.am/en/technical-content-writer-5
# 411/823 Est.: 68.67m.
# https://staff.am/en/hh-tavusi-marzi-aygehoviti-mijnakarg-dproc-poak-i-tnoreni-paston-zbagecnelu-hamar
# 412/823 Est.: 68.5m.
# https://staff.am/en/anvtangutyan-asxatakic-igakan
# 413/823 Est.: 68.33m.
# https://staff.am/en/software-engineer-59
# 414/823 Est.: 68.17m.
# https://staff.am/en/embedded-software-engineer
# 415/823 Est.: 68.0m.
# https://staff.am/en/manual-qa-engineer-132
# 416/823 Est.: 67.83m.
# https://staff.am/en/sales-manager-274
# 417/823 Est.: 67.67m.
# https://staff.am/en/angular-developer-39
# 418/823 Est.: 67.5m.
# https://staff.am/en/accountant-340
# 419/823 Est.: 67.33m.
# https://staff.am/en/corporate-banking-project-manager
# 420/823 Est.: 67.17m.
# https://staff.am/en/responsible-for-informational-security
# 421/823 Est.: 67.0m.
# https://staff.am/en/project-manager-internship---perfect-or-native-english-2
# 422/823 Est.: 66.83m.
# https://staff.am/en/swedish-audiobook-speaker-translator---native-speaker-level-only-part-time
# 423/823 Est.: 66.67m.
# https://staff.am/en/spanish-audiobook-speaker-translator---native-speaker-level-only-part-time
# 424/823 Est.: 66.5m.
# https://staff.am/en/business-analyst-for-digitalization-projects
# 425/823 Est.: 66.33m.
# https://staff.am/en/slovenian-audiobook-speaker-translator---native-speaker-level-only-part-time
# 426/823 Est.: 66.17m.
# https://staff.am/en/slovak-audiobook-speaker-translator---native-speaker-level-only-part-time
# 427/823 Est.: 66.0m.
# https://staff.am/en/romanian-audiobook-speaker-translator---native-speaker-level-only-part-time
# 428/823 Est.: 65.83m.
# https://staff.am/en/portuguese-audiobook-speaker-translator---native-speaker-level-only-part-time
# 429/823 Est.: 65.67m.
# https://staff.am/en/polish-audiobook-speaker-translator---native-speaker-level-only-part-time
# 430/823 Est.: 65.5m.
# https://staff.am/en/lithuanian-audiobook-speaker-translator---native-speaker-level-only-part-time
# 431/823 Est.: 65.33m.
# https://staff.am/en/latvian-audiobook-speaker-translator---native-speaker-level-only-part-time
# 432/823 Est.: 65.17m.
# https://staff.am/en/italian-audiobook-speaker-translator---native-speaker-level-only-part-time
# 433/823 Est.: 65.0m.
# https://staff.am/en/hungarian-audiobook-speaker-translator---native-speaker-level-only-part-time
# 434/823 Est.: 64.83m.
# https://staff.am/en/greek-audiobook-speaker-translator---native-speaker-level-only-part-time
# 435/823 Est.: 64.67m.
# https://staff.am/en/german-audiobook-speaker-translator---native-speaker-level-only-part-time
# 436/823 Est.: 64.5m.
# https://staff.am/en/french-audiobook-speaker-translator---native-speaker-level-only-part-time
# 437/823 Est.: 64.33m.
# https://staff.am/en/finnish-audiobook-speaker-translator---native-speaker-level-only-part-time
# 438/823 Est.: 64.17m.
# https://staff.am/en/estonian-audiobook-speaker-translator---native-speaker-level-only-part-time
# 439/823 Est.: 64.0m.
# https://staff.am/en/english-audiobook-speaker-translator---native-speaker-level-only-part-time
# 440/823 Est.: 63.83m.
# https://staff.am/en/dutch-audiobook-speaker-translator---native-speaker-level-only-part-time
# 441/823 Est.: 63.67m.
# https://staff.am/en/danish-audiobook-speaker-translator---native-speaker-level-only-part-time
# 442/823 Est.: 63.5m.
# https://staff.am/en/czech-audiobook-speaker-translator---native-speaker-level-only-part-time
# 443/823 Est.: 63.33m.
# https://staff.am/en/croatian-audiobook-speaker-translator---native-speaker-level-only-part-time
# 444/823 Est.: 63.17m.
# https://staff.am/en/bulgarian-audiobook-speaker-translator---native-speaker-level-only-part-time
# 445/823 Est.: 63.0m.
# https://staff.am/en/qa-coordinator
# 446/823 Est.: 62.83m.
# https://staff.am/en/it-support-engineer-245-shift-1
# 447/823 Est.: 62.67m.
# https://staff.am/en/ui-ux-designer-7
# 448/823 Est.: 62.5m.
# https://staff.am/en/customer-support-agent-2
# 449/823 Est.: 62.33m.
# https://staff.am/en/it-specialist-35
# 450/823 Est.: 62.17m.
# https://staff.am/en/technical-specialist-5
# 451/823 Est.: 62.0m.
# https://staff.am/en/credit-analyst-corporate-customers-credit-department
# 452/823 Est.: 61.83m.
# https://staff.am/en/sommelier-2
# 453/823 Est.: 61.67m.
# https://staff.am/en/product-owner-86
# 454/823 Est.: 61.5m.
# https://staff.am/en/assistant-to-chief-product-officer-1
# 455/823 Est.: 61.33m.
# https://staff.am/en/call-center-specialist-mixed-shift-1
# 456/823 Est.: 61.17m.
# https://staff.am/en/specialist-of-telephone-negotiations
# 457/823 Est.: 61.0m.
# https://staff.am/en/sales-and-service-specialist-33
# 458/823 Est.: 60.83m.
# https://staff.am/en/corporate-sales-manager-14
# 459/823 Est.: 60.67m.
# https://staff.am/en/call-centre-specialist-6
# 460/823 Est.: 60.5m.
# https://staff.am/en/executive-assistant-58
# 461/823 Est.: 60.33m.
# https://staff.am/en/home-sales-specialist-1
# 462/823 Est.: 60.17m.
# https://staff.am/en/senior-software-developer-11
# 463/823 Est.: 60.0m.
# https://staff.am/en/vcarumneri-xorhrdatu-1
# 464/823 Est.: 59.83m.
# https://staff.am/en/senior-python-developer-17
# 465/823 Est.: 59.67m.
# https://staff.am/en/search-marketing-analyst
# 466/823 Est.: 59.5m.
# https://staff.am/en/senior-react-native-developer-4
# 467/823 Est.: 59.33m.
# https://staff.am/en/accountant-339
# 468/823 Est.: 59.17m.
# https://staff.am/en/net
# 469/823 Est.: 59.0m.
# https://staff.am/en/instructor-7
# 470/823 Est.: 58.83m.
# https://staff.am/en/hh-syuniki-marzi-orotani-himnakan-dproc-poak-i-gorcadir-marmni-tnoreni-paston-zbagecnelu-hamar
# 471/823 Est.: 58.67m.
# https://staff.am/en/hh-tavusi-marzi-dilijani-tiv-4-himnakan-dproc-poak-i-tnoreni-paston-zbagecnelu-hamar
# 472/823 Est.: 58.5m.
# https://staff.am/en/hasvetvutyunneri-bazni-masnaget
# 473/823 Est.: 58.33m.
# https://staff.am/en/1c-system-administrator-4
# 474/823 Est.: 58.17m.
# https://staff.am/en/hh-ararati-marzi-hovtaseni-v-mkrtcyani-anvan-mijnakarg-dproc-poak-i-gorcadir-marmni-tnoreni-paston-zbagecnelu-hamar
# 475/823 Est.: 58.0m.
# https://staff.am/en/erevani-h-avetisyani-anvan-tiv-74-himnakan-dproc-poak-i-tnoreni-paston-zbagecnelu-hamar
# 476/823 Est.: 57.83m.
# https://staff.am/en/reservation-and-ticketing-agent
# 477/823 Est.: 57.67m.
# https://staff.am/en/maksayin-jevakerpumneri-masnaget-19
# 478/823 Est.: 57.5m.
# https://staff.am/en/marketing-research-executive-1
# 479/823 Est.: 57.33m.
# https://staff.am/en/system-administrator-99
# 480/823 Est.: 57.17m.
# https://staff.am/en/quality-engineering-manager-23614
# 481/823 Est.: 57.0m.
# https://staff.am/en/senior-rd-engineer-23332
# 482/823 Est.: 56.83m.
# https://staff.am/en/junior-asic-digital-design-engineer-23322
# 483/823 Est.: 56.67m.
# https://staff.am/en/senior-qa-engineer-23102
# 484/823 Est.: 56.5m.
# https://staff.am/en/junior-ams-circuit-design-engineer-23084
# 485/823 Est.: 56.33m.
# https://staff.am/en/mid-level-rd-engineer-22796
# 486/823 Est.: 56.17m.
# https://staff.am/en/ams-layout-design-supervisor-22744
# 487/823 Est.: 56.0m.
# https://staff.am/en/mid-level-ams-circuit-design-engineer22378br-9
# 488/823 Est.: 55.83m.
# https://staff.am/en/mid-level-ams-layout-design-engineer22346br-6
# 489/823 Est.: 55.67m.
# https://staff.am/en/project-admin-manager22313br-12
# 490/823 Est.: 55.5m.
# https://staff.am/en/junior-quality-engineer20793br-12
# 491/823 Est.: 55.33m.
# https://staff.am/en/senior-software-engineer22294br-12
# 492/823 Est.: 55.17m.
# https://staff.am/en/senior-ams-circuit-design-engineer22155br-12
# 493/823 Est.: 55.0m.
# https://staff.am/en/mid-level-ams-circuit-design-engineer21305br-19
# 494/823 Est.: 54.83m.
# https://staff.am/en/database-administrator-76
# 495/823 Est.: 54.67m.
# https://staff.am/en/ams-circuit-design-engineer-staff21273br-13
# 496/823 Est.: 54.5m.
# https://staff.am/en/senior-ams-layout-design-engineer20901br-12
# 497/823 Est.: 54.33m.
# https://staff.am/en/senior-rd-manager-20650
# 498/823 Est.: 54.17m.
# https://staff.am/en/automation-systems-support-and-educational-service-specialist-1
# 499/823 Est.: 54.0m.
# https://staff.am/en/digital-customer-service-specialist-mixed-shift-2
# 500/823 Est.: 53.83m.
# https://staff.am/en/senior-python-developer-18
# 501/823 Est.: 53.67m.
# https://staff.am/en/senior-php-developer-57
# 502/823 Est.: 53.5m.
# https://staff.am/en/preseller-61
# 503/823 Est.: 53.33m.
# https://staff.am/en/program-coordinator-8
# 504/823 Est.: 53.17m.
# https://staff.am/en/arevtrayin-marketingi-masnaget-1
# 505/823 Est.: 53.0m.
# https://staff.am/en/center-dr-bubnovskogo
# 506/823 Est.: 52.83m.
# https://staff.am/en/varkayin-masnaget-vedi-masnacyugum-5
# 507/823 Est.: 52.67m.
# https://staff.am/en/glxavor-hasvapahi-tegakal-9
# 508/823 Est.: 52.5m.
# https://staff.am/en/vacarki-masnaget-25
# 509/823 Est.: 52.33m.
# https://staff.am/en/hr-assistant-26
# 510/823 Est.: 52.17m.
# https://staff.am/en/live-chat-advisor
# 511/823 Est.: 52.0m.
# https://staff.am/en/customer-care-specialist-28
# 512/823 Est.: 51.83m.
# https://staff.am/en/online-sales-projects-manager
# 513/823 Est.: 51.67m.
# New Field to be scraped
# New Field to be scraped
# New Field to be scraped
# New Field to be scraped
# New Field to be scraped
# https://staff.am/en/react-js-developer-28
# 514/823 Est.: 51.5m.
# https://staff.am/en/receptionist-155
# 515/823 Est.: 51.33m.
# https://staff.am/en/logistics-coordinatordispatcher-13
# 516/823 Est.: 51.17m.
# https://staff.am/en/driver-21
# 517/823 Est.: 51.0m.
# https://staff.am/en/product-owner-83
# 518/823 Est.: 50.83m.
# https://staff.am/en/senior-software-developer-8
# 519/823 Est.: 50.67m.
# https://staff.am/en/glxavor-hasvapah-36
# 520/823 Est.: 50.5m.
# https://staff.am/en/medical-representative-34
# 521/823 Est.: 50.33m.
# https://staff.am/en/mid-nodejs-developer-1
# 522/823 Est.: 50.17m.
# https://staff.am/en/business-analyst-50
# 523/823 Est.: 50.0m.
# https://staff.am/en/software-developer-51
# 524/823 Est.: 49.83m.
# https://staff.am/en/arabic-speaking-salessupport-representative-1
# 525/823 Est.: 49.67m.
# https://staff.am/en/senior-back-end-developer-15
# 526/823 Est.: 49.5m.
# https://staff.am/en/ventilation-system-engineer-2
# 527/823 Est.: 49.33m.
# https://staff.am/en/anjnakazmi-verapatrastman-ev-zargacman-masnaget
# 528/823 Est.: 49.17m.
# https://staff.am/en/office-applications-development-senior-specialist-2
# 529/823 Est.: 49.0m.
# https://staff.am/en/dmp-amp-bi-lead-specialist-4
# 530/823 Est.: 48.83m.
# https://staff.am/en/seo-specialist-49
# 531/823 Est.: 48.67m.
# https://staff.am/en/kontent-menedzer-5
# 532/823 Est.: 48.5m.
# https://staff.am/en/sales-manager-273
# 533/823 Est.: 48.33m.
# https://staff.am/en/design-engineer
# 534/823 Est.: 48.17m.
# https://staff.am/en/smm-masnaget-37
# 535/823 Est.: 48.0m.
# https://staff.am/en/export-manager-10
# 536/823 Est.: 47.83m.
# https://staff.am/en/sales-consultant-247
# 537/823 Est.: 47.67m.
# https://staff.am/en/outgoing-and-incoming-tour-manager
# 538/823 Est.: 47.5m.
# https://staff.am/en/senior-net-developer-107
# 539/823 Est.: 47.33m.
# https://staff.am/en/experienced-net-developer-10
# 540/823 Est.: 47.17m.
# https://staff.am/en/yii2laravel-react-developer
# 541/823 Est.: 47.0m.
# https://staff.am/en/gnumneri-masnaget-18
# 542/823 Est.: 46.83m.
# https://staff.am/en/financial-controller-9
# 543/823 Est.: 46.67m.
# https://staff.am/en/software-architect-12
# 544/823 Est.: 46.5m.
# https://staff.am/en/ims-network-engineer-9
# 545/823 Est.: 46.33m.
# https://staff.am/en/mobile-core-network-engineer-9
# 546/823 Est.: 46.17m.
# https://staff.am/en/database-developer-34
# 547/823 Est.: 46.0m.
# https://staff.am/en/ios-developer-158
# 548/823 Est.: 45.83m.
# https://staff.am/en/java-developer-69
# 549/823 Est.: 45.67m.
# https://staff.am/en/mrk
# 550/823 Est.: 45.5m.
# https://staff.am/en/cnet-developer-9
# 551/823 Est.: 45.33m.
# https://staff.am/en/senior-full-stack-web-developer-11
# 552/823 Est.: 45.17m.
# https://staff.am/en/sales-manager-265
# 553/823 Est.: 45.0m.
# https://staff.am/en/mobile-developer-2
# 554/823 Est.: 44.83m.
# https://staff.am/en/lawyer-64
# 555/823 Est.: 44.67m.
# https://staff.am/en/devops-engineer-141
# 556/823 Est.: 44.5m.
# https://staff.am/en/project-manager-175
# 557/823 Est.: 44.33m.
# https://staff.am/en/senior-web-developer---reactjs-7
# 558/823 Est.: 44.17m.
# https://staff.am/en/js-developer-8
# 559/823 Est.: 44.0m.
# https://staff.am/en/copywriter-40
# 560/823 Est.: 43.83m.
# https://staff.am/en/research-and-outreach-specialist
# 561/823 Est.: 43.67m.
# https://staff.am/en/social-media-specialist-8
# 562/823 Est.: 43.5m.
# https://staff.am/en/asxatakicneri-nergravman-ev-adaptacman-arajatar-masnaget-1
# 563/823 Est.: 43.33m.
# https://staff.am/en/sales-manager-farsi-9
# 564/823 Est.: 43.17m.
# https://staff.am/en/sales-consultant-245
# 565/823 Est.: 43.0m.
# https://staff.am/en/vacarog-xorhrdatu-51
# 566/823 Est.: 42.83m.
# https://staff.am/en/spanish-speaking-salessupport-representative-1
# 567/823 Est.: 42.67m.
# https://staff.am/en/sales-manager-270
# 568/823 Est.: 42.5m.
# https://staff.am/en/uiux-designer-249
# 569/823 Est.: 42.33m.
# https://staff.am/en/full-stack-javascript-developer-16
# 570/823 Est.: 42.17m.
# https://staff.am/en/hacaxordneri-spasarkman-masnagetner
# 571/823 Est.: 42.0m.
# https://staff.am/en/cto-assistant-1
# 572/823 Est.: 41.83m.
# https://staff.am/en/french-speaking-incoming-tour-manager-1
# 573/823 Est.: 41.67m.
# https://staff.am/en/customer-engineer-3
# 574/823 Est.: 41.5m.
# https://staff.am/en/senior-documentation-specialist-5
# 575/823 Est.: 41.33m.
# https://staff.am/en/hr-specialist-87
# 576/823 Est.: 41.17m.
# https://staff.am/en/mrk-gorcavar-6
# 577/823 Est.: 41.0m.
# https://staff.am/en/senior-android-developer-74
# 578/823 Est.: 40.83m.
# https://staff.am/en/elektronikayi-inzener
# 579/823 Est.: 40.67m.
# https://staff.am/en/jermatexnik
# 580/823 Est.: 40.5m.
# https://staff.am/en/english-specialist-4
# 581/823 Est.: 40.33m.
# https://staff.am/en/chief-accountant-59
# 582/823 Est.: 40.17m.
# https://staff.am/en/tax-assistant
# 583/823 Est.: 40.0m.
# https://staff.am/en/anhatakan-menejer-premium-dasi-masnacyug
# 584/823 Est.: 39.83m.
# https://staff.am/en/administrative-assistant-118
# 585/823 Est.: 39.67m.
# https://staff.am/en/call-center-specialist-62
# 586/823 Est.: 39.5m.
# https://staff.am/en/data-platform-engineer-with-postgresql-skills-4
# 587/823 Est.: 39.33m.
# https://staff.am/en/senior-web-designer
# 588/823 Est.: 39.17m.
# https://staff.am/en/senior-ruby-developer-12
# 589/823 Est.: 39.0m.
# https://staff.am/en/senior-front-end-developer-with-elm-experience
# 590/823 Est.: 38.83m.
# https://staff.am/en/hacaxordneri-spasarkman-masnaget-29
# 591/823 Est.: 38.67m.
# https://staff.am/en/client-manager-10
# 592/823 Est.: 38.5m.
# https://staff.am/en/senior-qa-automation-c-engineer
# 593/823 Est.: 38.33m.
# https://staff.am/en/middle-perl-developer-4
# 594/823 Est.: 38.17m.
# https://staff.am/en/cassandra-administrator-4
# 595/823 Est.: 38.0m.
# https://staff.am/en/mechanic-18
# 596/823 Est.: 37.83m.
# https://staff.am/en/data-platform-engineer
# 597/823 Est.: 37.67m.
# https://staff.am/en/accountant-335
# 598/823 Est.: 37.5m.
# https://staff.am/en/qa-engineer-345
# 599/823 Est.: 37.33m.
# https://staff.am/en/front-desk-manager-19
# 600/823 Est.: 37.17m.
# https://staff.am/en/barjr-asxatavarjov-asxatank-mec-ciacan-marketneri-cancum
# 601/823 Est.: 37.0m.
# https://staff.am/en/it-project-manager-58
# 602/823 Est.: 36.83m.
# https://staff.am/en/sales-and-customer-service-center-senior-specialist-tashir-1
# 603/823 Est.: 36.67m.
# https://staff.am/en/sales-and-customer-service-center-specialist-berd-1
# 604/823 Est.: 36.5m.
# https://staff.am/en/in-vino-team-member
# 605/823 Est.: 36.33m.
# https://staff.am/en/it-recruiter-21
# 606/823 Est.: 36.17m.
# https://staff.am/en/customer-support-junior-manager-excellent-english
# 607/823 Est.: 36.0m.
# https://staff.am/en/nodejs-developer-51
# 608/823 Est.: 35.83m.
# https://staff.am/en/cook-10
# 609/823 Est.: 35.67m.
# https://staff.am/en/senior-qa-engineer-120
# 610/823 Est.: 35.5m.
# https://staff.am/en/experienced-manual-qa-engineer
# 611/823 Est.: 35.33m.
# https://staff.am/en/experienced-automation-qa-engineer
# 612/823 Est.: 35.17m.
# https://staff.am/en/glxavoravag-hasvapah-1
# 613/823 Est.: 35.0m.
# https://staff.am/en/laborant
# 614/823 Est.: 34.83m.
# https://staff.am/en/front-end-developer-208
# 615/823 Est.: 34.67m.
# https://staff.am/en/sogeuzayin-tntesutyan-bazni-peti-tegakal
# 616/823 Est.: 34.5m.
# https://staff.am/en/logist-menejer-vacarki-menejer
# 617/823 Est.: 34.33m.
# https://staff.am/en/logistic-department-coordinator
# 618/823 Est.: 34.17m.
# https://staff.am/en/uiux-designer-252
# 619/823 Est.: 34.0m.
# https://staff.am/en/hasvetar-31
# 620/823 Est.: 33.83m.
# https://staff.am/en/sales-and-customer-service-center-senior-specialist-vedi-1
# 621/823 Est.: 33.67m.
# https://staff.am/en/sales-specialist-49
# 622/823 Est.: 33.5m.
# https://staff.am/en/operator-cashier-5
# 623/823 Est.: 33.33m.
# New Field to be scraped
# https://staff.am/en/customer-service-agent-14
# 624/823 Est.: 33.17m.
# https://staff.am/en/operational-specialist-7
# 625/823 Est.: 33.0m.
# https://staff.am/en/project-manager-172
# 626/823 Est.: 32.83m.
# https://staff.am/en/junior-systems-administrator-7
# 627/823 Est.: 32.67m.
# New Field to be scraped
# New Field to be scraped
# https://staff.am/en/front-end-software-engineer-36
# 628/823 Est.: 32.5m.
# New Field to be scraped
# https://staff.am/en/administrative-coordinator-13
# 629/823 Est.: 32.33m.
# https://staff.am/en/qa-engineer-337
# 630/823 Est.: 32.17m.
# https://staff.am/en/senior-full-stack-developer-net-corec-1
# 631/823 Est.: 32.0m.
# https://staff.am/en/middle-full-stack-developer-net-corec-1
# 632/823 Est.: 31.83m.
# https://staff.am/en/junior-full-stack-razrabotcik-net-corec-1
# 633/823 Est.: 31.67m.
# https://staff.am/en/pr-specialist-20
# 634/823 Est.: 31.5m.
# https://staff.am/en/mid-graphic-designer-1
# 635/823 Est.: 31.33m.
# https://staff.am/en/software-engineering-manager-6
# 636/823 Est.: 31.17m.
# https://staff.am/en/senior-reactjs-engineer
# 637/823 Est.: 31.0m.
# https://staff.am/en/zangeri-kentroni-operatorner-2
# 638/823 Est.: 30.83m.
# https://staff.am/en/senior-ios-developer-57
# 639/823 Est.: 30.67m.
# https://staff.am/en/nergna-tur-menejer-germaneren-lezvi-imacutyamb
# 640/823 Est.: 30.5m.
# https://staff.am/en/tumo-center-manager-gyumri
# 641/823 Est.: 30.33m.
# https://staff.am/en/fundraising-officer
# 642/823 Est.: 30.17m.
# https://staff.am/en/database-administrator-73
# 643/823 Est.: 30.0m.
# https://staff.am/en/it-security-specialist-8
# 644/823 Est.: 29.83m.
# https://staff.am/en/contact-center-specialist-25
# 645/823 Est.: 29.67m.
# https://staff.am/en/videotesahskman-masnaget-1
# 646/823 Est.: 29.5m.
# https://staff.am/en/customer-service-specialist-51
# 647/823 Est.: 29.33m.
# https://staff.am/en/net-developer-127
# 648/823 Est.: 29.17m.
# https://staff.am/en/cto
# 649/823 Est.: 29.0m.
# https://staff.am/en/director-human-resources
# 650/823 Est.: 28.83m.
# https://staff.am/en/accountant-334
# 651/823 Est.: 28.67m.
# https://staff.am/en/tour-guide-4
# 652/823 Est.: 28.5m.
# https://staff.am/en/qa-engineer-334
# 653/823 Est.: 28.33m.
# New Field to be scraped
# New Field to be scraped
# New Field to be scraped
# https://staff.am/en/sales-manager-269
# 654/823 Est.: 28.17m.
# https://staff.am/en/texnikakan-ajakcman-masnaget-15
# 655/823 Est.: 28.0m.
# https://staff.am/en/senior-front-end-developer-41
# 656/823 Est.: 27.83m.
# https://staff.am/en/glxavor-hasvapah-33
# 657/823 Est.: 27.67m.
# https://staff.am/en/react-developer-seniormiddle
# 658/823 Est.: 27.5m.
# https://staff.am/en/manual-qa-specialist-24
# 659/823 Est.: 27.33m.
# https://staff.am/en/presellers-in-all-ra-regions-and-nkr-1
# 660/823 Est.: 27.17m.
# https://staff.am/en/senior-it-monitoring-specialist-12
# 661/823 Est.: 27.0m.
# https://staff.am/en/senior-it-operations-engineer-16
# 662/823 Est.: 26.83m.
# https://staff.am/en/senior-front-end-engineer-12
# 663/823 Est.: 26.67m.
# https://staff.am/en/senior-system-administrator-19
# 664/823 Est.: 26.5m.
# https://staff.am/en/technical-support-specialist-90
# 665/823 Est.: 26.33m.
# https://staff.am/en/b2b-sales-manager-18
# 666/823 Est.: 26.17m.
# https://staff.am/en/hr-specialist-84
# 667/823 Est.: 26.0m.
# https://staff.am/en/community-managersupport-specialist-16
# 668/823 Est.: 25.83m.
# https://staff.am/en/business-development-specialist-12
# 669/823 Est.: 25.67m.
# https://staff.am/en/senior-android-developer-77
# 670/823 Est.: 25.5m.
# https://staff.am/en/hh-loru-marzi-stepanavani-tiv-3-himnakan-dproc-poak-i-tnoreni-paston-zbagecnelu-hamar-4
# 671/823 Est.: 25.33m.
# https://staff.am/en/head-of-marketing-department-14
# 672/823 Est.: 25.17m.
# https://staff.am/en/sales-manager-268
# 673/823 Est.: 25.0m.
# https://staff.am/en/gallery-representative-3
# 674/823 Est.: 24.83m.
# https://staff.am/en/senior-angularjs-developer-19
# 675/823 Est.: 24.67m.
# https://staff.am/en/hh-loru-marzi-ahnijori-himnakan-dproc-poak-i-tnoreni-paston-zbagecnelu-hamar-4
# 676/823 Est.: 24.5m.
# https://staff.am/en/senior-android-developer-71
# 677/823 Est.: 24.33m.
# https://staff.am/en/js-developer-with-reactjs-experience-1
# 678/823 Est.: 24.17m.
# https://staff.am/en/full-stack-net-developer-12
# 679/823 Est.: 24.0m.
# https://staff.am/en/support-specialist-9
# 680/823 Est.: 23.83m.
# https://staff.am/en/business-analyst-47
# 681/823 Est.: 23.67m.
# New Field to be scraped
# https://staff.am/en/tumo-center-manager-stepanakert
# 682/823 Est.: 23.5m.
# https://staff.am/en/product-manager-product-owner-24
# 683/823 Est.: 23.33m.
# https://staff.am/en/product-manager-99
# 684/823 Est.: 23.17m.
# https://staff.am/en/devops-system-engineer-18
# 685/823 Est.: 23.0m.
# https://staff.am/en/marketing-specialist-186
# 686/823 Est.: 22.83m.
# https://staff.am/en/php-developer-freelance
# 687/823 Est.: 22.67m.
# https://staff.am/en/varord-arakic-11
# 688/823 Est.: 22.5m.
# https://staff.am/en/hr-manager-85
# 689/823 Est.: 22.33m.
# https://staff.am/en/heraxosavaruhi-operator
# 690/823 Est.: 22.17m.
# https://staff.am/en/nodejs-backend-developer-12
# 691/823 Est.: 22.0m.
# https://staff.am/en/tegagrakan-geodezist-4
# 692/823 Est.: 21.83m.
# https://staff.am/en/foreman-4
# 693/823 Est.: 21.67m.
# https://staff.am/en/sportsbook-content-officer-4
# 694/823 Est.: 21.5m.
# https://staff.am/en/sports-trading-operations-manager-1
# 695/823 Est.: 21.33m.
# https://staff.am/en/senior-javascript-developer-28
# 696/823 Est.: 21.17m.
# https://staff.am/en/php-developer-174
# 697/823 Est.: 21.0m.
# New Field to be scraped
# New Field to be scraped
# https://staff.am/en/logistics-specialist-11
# 698/823 Est.: 20.83m.
# https://staff.am/en/angular-developer-36
# 699/823 Est.: 20.67m.
# https://staff.am/en/uiux-product-manager-1
# 700/823 Est.: 20.5m.
# https://staff.am/en/quality-control-specialist-9
# 701/823 Est.: 20.33m.
# https://staff.am/en/nkarcuhi-dizayner-1
# 702/823 Est.: 20.17m.
# https://staff.am/en/brand-manager-56
# 703/823 Est.: 20.0m.
# https://staff.am/en/senior-reactjs-developer-52
# 704/823 Est.: 19.83m.
# https://staff.am/en/training-and-internship-program-for-sas-programmers
# 705/823 Est.: 19.67m.
# https://staff.am/en/qa-engineer-331
# 706/823 Est.: 19.5m.
# https://staff.am/en/senior-accountant-46
# 707/823 Est.: 19.33m.
# https://staff.am/en/technical-project-coordinator-4
# 708/823 Est.: 19.17m.
# https://staff.am/en/loan-officer-22
# 709/823 Est.: 19.0m.
# https://staff.am/en/employee-of-risk-management-department
# 710/823 Est.: 18.83m.
# https://staff.am/en/sales-team-supervisor
# 711/823 Est.: 18.67m.
# https://staff.am/en/qa-automation-engineer-backend-2
# 712/823 Est.: 18.5m.
# https://staff.am/en/senior-qa-automation-engineer-mobile-12
# 713/823 Est.: 18.33m.
# https://staff.am/en/ios-developer-156
# 714/823 Est.: 18.17m.
# https://staff.am/en/android-developer-145
# 715/823 Est.: 18.0m.
# https://staff.am/en/senior-nodejs-developer-32
# 716/823 Est.: 17.83m.
# https://staff.am/en/systems-architect-4
# 717/823 Est.: 17.67m.
# https://staff.am/en/systems-analyst-40
# 718/823 Est.: 17.5m.
# https://staff.am/en/sukayi-zargacnan-menejer-1
# 719/823 Est.: 17.33m.
# New Field to be scraped
# https://staff.am/en/accountant-333
# 720/823 Est.: 17.17m.
# https://staff.am/en/turkish-speaking-projects-implementation-manager
# 721/823 Est.: 17.0m.
# https://staff.am/en/istqb-certified-qa-engineer-1
# 722/823 Est.: 16.83m.
# https://staff.am/en/manual-qa-engineer-108
# 723/823 Est.: 16.67m.
# https://staff.am/en/artahanman-ev-nermucman-pastatgteri-jevakerpman-ev-logistikayi-masnaget
# 724/823 Est.: 16.5m.
# https://staff.am/en/accountant-assistant-9
# 725/823 Est.: 16.33m.
# https://staff.am/en/provider
# 726/823 Est.: 16.17m.
# https://staff.am/en/senior-c-developer-88
# 727/823 Est.: 16.0m.
# https://staff.am/en/head-of-commercial-department
# 728/823 Est.: 15.83m.
# https://staff.am/en/contact-center-hero-18
# 729/823 Est.: 15.67m.
# https://staff.am/en/mexanik-16
# 730/823 Est.: 15.5m.
# https://staff.am/en/hh-kotayki-marzi-saralanji-himnakan-dproc-poak-i-gorcadir-marmni-tnoreni-pastonn-zbagecnelu-hamar-4
# 731/823 Est.: 15.33m.
# https://staff.am/en/sales-specialist-46
# 732/823 Est.: 15.17m.
# https://staff.am/en/uiux-designer-246
# 733/823 Est.: 15.0m.
# https://staff.am/en/account-manager-36
# 734/823 Est.: 14.83m.
# https://staff.am/en/front-end-developer-intern-7
# 735/823 Est.: 14.67m.
# https://staff.am/en/account-manager-33
# 736/823 Est.: 14.5m.
# https://staff.am/en/banquet-chef
# 737/823 Est.: 14.33m.
# https://staff.am/en/manual-qa
# 738/823 Est.: 14.17m.
# https://staff.am/en/smm-specialist-197
# 739/823 Est.: 14.0m.
# https://staff.am/en/junior-software-test-automation-engineer
# 740/823 Est.: 13.83m.
# https://staff.am/en/senior-software-quality-engineer
# 741/823 Est.: 13.67m.
# https://staff.am/en/mid-level-software-quality-engineer
# 742/823 Est.: 13.5m.
# https://staff.am/en/assistant-restaurant-manager
# 743/823 Est.: 13.33m.
# https://staff.am/en/tour-manager-for-english-speaking-markets-6
# 744/823 Est.: 13.17m.
# https://staff.am/en/customer-service-representative-17
# 745/823 Est.: 13.0m.
# https://staff.am/en/call-center-operator-55
# 746/823 Est.: 12.83m.
# https://staff.am/en/xorhrdatu---vacarog-1
# 747/823 Est.: 12.67m.
# https://staff.am/en/kahuyki-vacarki-menejer
# 748/823 Est.: 12.5m.
# https://staff.am/en/frontend-engineer-reactjs
# 749/823 Est.: 12.33m.
# https://staff.am/en/menejer-sukayi-zargacman-patasxanatu-1
# 750/823 Est.: 12.17m.
# https://staff.am/en/credit-sale-specialist-1
# 751/823 Est.: 12.0m.
# https://staff.am/en/marketing-manager-100
# 752/823 Est.: 11.83m.
# https://staff.am/en/experienced-qa-specialist-9
# 753/823 Est.: 11.67m.
# https://staff.am/en/junior-full-stack-developer-7
# 754/823 Est.: 11.5m.
# https://staff.am/en/junior-java-software-engineer
# 755/823 Est.: 11.33m.
# https://staff.am/en/junior-ios-developer-6
# 756/823 Est.: 11.17m.
# https://staff.am/en/senior-java-software-engineer-52
# 757/823 Est.: 11.0m.
# https://staff.am/en/mid-level-java-software-engineer-1
# 758/823 Est.: 10.83m.
# https://staff.am/en/senior-front-end-software-engineer-14
# 759/823 Est.: 10.67m.
# https://staff.am/en/senior-system-engineer-19
# 760/823 Est.: 10.5m.
# https://staff.am/en/senior-network-engineer-9
# 761/823 Est.: 10.33m.
# https://staff.am/en/database-administrator-oracle-18
# 762/823 Est.: 10.17m.
# https://staff.am/en/restaurant-manager-21
# 763/823 Est.: 10.0m.
# https://staff.am/en/java-engineer-27
# 764/823 Est.: 9.83m.
# https://staff.am/en/senior-ios-developer-54
# 765/823 Est.: 9.67m.
# https://staff.am/en/senior-back-end-engineer-ml-team-21
# 766/823 Est.: 9.5m.
# https://staff.am/en/senior-c-developer-85
# 767/823 Est.: 9.33m.
# https://staff.am/en/director-content-programming-and-marketing-3
# 768/823 Est.: 9.17m.
# https://staff.am/en/director-growth-marketing-15
# 769/823 Est.: 9.0m.
# https://staff.am/en/mobile-software-engineer-in-test-12
# 770/823 Est.: 8.83m.
# https://staff.am/en/sukayi-zargacman-patasxanatu-15
# 771/823 Est.: 8.67m.
# https://staff.am/en/it-monitoring-specialist-247-shift-6
# 772/823 Est.: 8.5m.
# https://staff.am/en/engineering-manager-38
# 773/823 Est.: 8.33m.
# https://staff.am/en/big-data-engineer-54
# 774/823 Est.: 8.17m.
# https://staff.am/en/release-engineer-mobile-15
# 775/823 Est.: 8.0m.
# https://staff.am/en/waiter-22
# 776/823 Est.: 7.83m.
# https://staff.am/en/project-manager-169
# 777/823 Est.: 7.67m.
# https://staff.am/en/naxahasiv-kazmog-1
# 778/823 Est.: 7.5m.
# https://staff.am/en/customer-service-representative-11
# 779/823 Est.: 7.33m.
# https://staff.am/en/sales-consultant-243
# 780/823 Est.: 7.17m.
# https://staff.am/en/it-administrator-9
# 781/823 Est.: 7.0m.
# https://staff.am/en/english-speaking-sales-representative-morning-shift-9
# 782/823 Est.: 6.83m.
# https://staff.am/en/english-speaking-sales-representative-12
# 783/823 Est.: 6.67m.
# https://staff.am/en/customer-support-agent---french-language-mixed-shift-1
# 784/823 Est.: 6.5m.
# https://staff.am/en/customer-support-agent---arabic-language-mixed-shifts-1
# 785/823 Est.: 6.33m.
# https://staff.am/en/procurment-specialist
# 786/823 Est.: 6.17m.
# https://staff.am/en/customer-support-agent---german-language-mixed-shifts-12
# 787/823 Est.: 6.0m.
# https://staff.am/en/tour-and-transport-operator-for-french-and-english-speaking-market-4
# 788/823 Est.: 5.83m.
# https://staff.am/en/german-speaking-market-tour-agent-4
# 789/823 Est.: 5.67m.
# https://staff.am/en/marketing-manager-102
# 790/823 Est.: 5.5m.
# https://staff.am/en/online-support-service-9
# 791/823 Est.: 5.33m.
# https://staff.am/en/front-end-developer-204
# 792/823 Est.: 5.17m.
# https://staff.am/en/customer-support-agent---polish-language-mixed-shifts-6
# 793/823 Est.: 5.0m.
# https://staff.am/en/customer-support-agent--englishrussian-languages-mixed-shifts-6
# 794/823 Est.: 4.83m.
# https://staff.am/en/affiliate-team-lead-13
# 795/823 Est.: 4.67m.
# https://staff.am/en/qa-4
# 796/823 Est.: 4.5m.
# https://staff.am/en/hacaxordneri-spasarkman-masnaget-20
# 797/823 Est.: 4.33m.
# https://staff.am/en/hacaxordneri-spasarkman-masnaget-17
# 798/823 Est.: 4.17m.
# https://staff.am/en/full-stack-javascript-developer-10
# 799/823 Est.: 4.0m.
# https://staff.am/en/corporate-sales-manager-15
# 800/823 Est.: 3.83m.
# https://staff.am/en/incoming-and-outgoing-tourism-manager-airtickets-specialist-1
# 801/823 Est.: 3.67m.
# https://staff.am/en/graphic-designer-293
# 802/823 Est.: 3.5m.
# https://staff.am/en/arevayin-elektrakayanneri-spasarkog
# 803/823 Est.: 3.33m.
# https://staff.am/en/inzener-naxagcog-energetikayi-olortum-4
# 804/823 Est.: 3.17m.
# https://staff.am/en/mardkayin-resursneri-karavarman-masnaget-hr
# 805/823 Est.: 3.0m.
# https://staff.am/en/artcraft-teacher
# 806/823 Est.: 2.83m.
# https://staff.am/en/logistics-company-branch-manager-all-state
# 807/823 Est.: 2.67m.
# https://staff.am/en/salesperson-9
# 808/823 Est.: 2.5m.
# https://staff.am/en/it-project-manager-55
# 809/823 Est.: 2.33m.
# https://staff.am/en/senior-qa-engineer-115
# 810/823 Est.: 2.17m.
# https://staff.am/en/anvtangutyan-asxatakic-17
# 811/823 Est.: 2.0m.
# https://staff.am/en/tesahskman-operator-14
# 812/823 Est.: 1.83m.
# https://staff.am/en/firmayin-xanuti-vacaroguhi-22
# 813/823 Est.: 1.67m.
# https://staff.am/en/graphic-designer-290
# 814/823 Est.: 1.5m.
# https://staff.am/en/illustrator-21
# 815/823 Est.: 1.33m.
# https://staff.am/en/hospitable-restaurant-3
# 816/823 Est.: 1.17m.
# https://staff.am/en/smm-specialist-195
# 817/823 Est.: 1.0m.
# https://staff.am/en/medical-representative-for-la-roche-posay-1
# 818/823 Est.: 0.83m.
# https://staff.am/en/senior-level-ios-developer-10
# 819/823 Est.: 0.67m.
# https://staff.am/en/content-manager-rewriter
# 820/823 Est.: 0.5m.
# https://staff.am/en/customer-service-specialist-52
# 821/823 Est.: 0.33m.
# https://staff.am/en/hh-siraki-marzi-bavrayi-mijnakarg-dproc-poak-gorcadir-marmni-tnoreni-paston-zbagecnelu-hamar
# 822/823 Est.: 0.17m.
# https://staff.am/en/hh-gegarkuniki-marzi-karcagbyuri-a-grigoryani-anvan-mijnakarg-dproc-poak-i-tnoreni-paston-zbagecnelu-hamar-4
# 823/823 Est.: 0.0m.
# Fri Jan 31 11:54:12 2020

# %%
extracted_data = pd.DataFrame(extracted_data)

# %%
for key in extracted_data.keys():
    print(key + ": " + str(len(extracted_data[key])))
# Out:
# Company_Title: 823
# Total_views: 823
# Followers: 823
# Active_Jobs: 823
# Jobs_History: 823
# Job_Views: 823
# Job_Title: 823
# Application_Deadline: 823
# Industry: 823
# Employment_term: 823
# Job_Category: 823
# Job_type: 823
# Job_Location: 823
# Salary: 823
# Job_description: 823
# Job_responsibilities: 683
# Required_qualifications: 751
# Required_candidate_level: 594
# Additional_information: 705
# Professional_skills: 708
# Soft_skills: 708
# : 10
# We_are_looking_for_a_qualified Graphic_Designer_to_join_our_team._This_is_an_opportunity_to_join_one_of_the_best_creative_agencies_in_the_region._You_will_work_closely_with_the_team_to_produce_creative,_visually_appealing_content_that_reflects_clients’_visions.: 1
# Արտադրանքի,_հումք-նյութերի_մանրէաբանական _ստուգումների_և_փորձաքննությունների իրականացում,սանիտարահիգիենիկ_պայմանների_վերահսկում։: 1
# Աթենք_ընկերության արտադրամասին_անհրաժեշտ_է_հաշվառող,_ով _իրականացնում_է_արտադրական_տ: 1
# ղամասերի_հումքային_շարժի_վերահսկում: 1
# Ստեկո-ն_ընդլայնելով _իր_թիմը,աշխատանքի_է_հրավիրում_վաճառող-խորհրդատուների: 1
# Interested_individuals_are_requested_to_send_their: 1
# and: 1
# to: 1
# Please,_clearly_mention_in_the_subject_line_"Online_Sales_Specialist"._Only_shortlisted_candidates_will_be_considered․_We_look_forward_to_your_applications!: 1
# Please_clearly_mention_that_you_have_heard_of_this_job_opportunity_on_staff.am: 1
# Անհրաժեշտ_է_մասնագետ,_ով՝: 1
# Qualifications: 1
# Non-Technical_Responsibilities: 1
# How_to_Apply: 1
# Send_your_CV_in_PDF_to: 1
# .: 1

# %%
rs = requests.get("https://staff.am/en/traffic-controller-2")
response = scrapy.http.HtmlResponse(url=rs.url, body=rs.text, encoding="utf-8")

# %%
with open("31.01.2020.json", "w") as file:
    file.write(json.dumps(extracted_data))
